# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
data_path = '/Users/olesialev/Downloads/data:/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum().sort_values(ascending=False).head(1)
# Out:
# Branch
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.groupby('City')['gross income'].sum().sort_values(ascending=False).head(1)
# Out:
# City
# Naypyitaw    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table(df, index='Branch', columns='Product line', values='Invoice ID', aggfunc='count')

# %%
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].sort_values(ascending=False).head(1)
# Out:
# Branch
# A    60
# Name: Electronic accessories, dtype: int64

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# 1.Гіпотеза про тип клієнта
#
# Чи відрізняється середній чек і кількість покупок між типами клієнтів (Customer type: Member vs Normal)?

# %%
type_of_client = pd.pivot_table(df, index='Customer type', values=['gross income', 'Total', 'Quantity'], aggfunc={'Total': 'mean', 'Quantity': 'sum', 'gross income': 'mean'})

# %%
type_of_client
# Out:
#                Quantity       Total  gross income
# Customer type
# Member             2785  327.791305     15.609110
# Normal             2725  318.122856     15.148707

# %% [markdown]
# Програма лояльності позитивно впливає на середній чек та прибутковість клієнтів, тому її розвиток може напряму підвищити загальний прибуток мережі супермаркетів. Отже, потрібно інвестувати в розвиток програми лояльності, оскільки Members приносять більше доходу.

# %% [markdown]
# 2.Гіпотеза про спосіб оплати
#
# Чи впливає спосіб оплати (Payment) на середній чек та кількість куплених товарів?

# %%
payment_result = df.groupby('Payment').agg({'Total': 'mean', 'Quantity': 'sum'})

# %%
payment_result
# Out:
#                   Total  Quantity
# Payment
# Cash         326.181890      1896
# Credit card  324.009878      1722
# Ewallet      318.820600      1892

# %% [markdown]
# Спосіб оплати впливає на поведінку покупців, тому правильно налаштовані стимули для певних платіжних методів можуть підвищити середній чек і загальний прибуток. Потрібно проаналізувати причини нижчої активності Credit card (можливо, комісії, повільніше обслуговування, менше акцій).

# %% [markdown]
# 3.Гіпотеза про гендер та категорії товарів
#
# Чи існує зв’язок між статтю покупця (Gender) та категоріями товарів (Product line), які купують найчастіше?

# %%
gender_result = pd.pivot_table(df, index = 'Gender', columns = 'Product line', values = 'Invoice ID', aggfunc = 'count')

# %%
gender_result
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                            84                   96                  90
# Male                              86                   82                  84
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                       64                  79                 88
# Male                         88                  81                 78

# %% [markdown]
# Отже, бачимо, що жінки частіше купують: Fashion accessories, Food and beverages, Sports and travel.
# Чоловіки частіше купують: Health and beauty, трохи більше Electronic accessories та Home and lifestyle.
# Можна запровадити персоналізовані промоакції - до прикладу, Fashion accessories - таргетувати на жіночу аудиторію, а у свою чергу, Health and beauty - імплементувати акції для чоловіків.
